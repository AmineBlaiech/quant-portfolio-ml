# %%
import yfinance as yf

data = yf.download(
    "AAPL",
    start="2018-01-01",
    end="2025-01-01"
)

data.head()
# Out:
# The kernel failed to start as the Python Environment '.venv (Python 3.13.13)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
